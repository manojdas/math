# %%
import wyth
import matplotlib
matplotlib.rcParams['text.usetex'] = True
import matplotlib.pyplot as plt
from importlib import reload

# %%
x,y = zip(*wyth.wyth_p_positions(30))

# %%
reload(wyth)
# Out:
# <module 'wyth' from '/Users/manoj.das@cheetahdigital.com/gitr/math/CGT/wyth.py'>

# %%
y
# Out:
# (0,
#  0,
#  2,
#  1,
#  5,
#  3,
#  7,
#  4,
#  10,
#  6,
#  13,
#  8,
#  15,
#  9,
#  18,
#  11,
#  20,
#  12,
#  23,
#  14,
#  26,
#  16,
#  28,
#  17,
#  31,
#  19,
#  34,
#  21,
#  36,
#  22,
#  39,
#  24,
#  41,
#  25,
#  44,
#  27,
#  47,
#  29,
#  49,
#  30,
#  52,
#  32,
#  54,
#  33,
#  57,
#  35,
#  60,
#  37,
#  62,
#  38,
#  65,
#  40,
#  68,
#  42,
#  70,
#  43,
#  73,
#  45,
#  75,
#  46,
#  78,
#  48)

# %%
plt.scatter(x, y)

# %%
fig, ax = plt.subplots(figsize=(10,10))
# ax = fig.add_axes([0.1,0.1,9.9,9.9])
# plt.title("Wythoff P Positons")
ax.plot(x1, y1, label='$\phi \cdot x$')
ax.plot(x, y2, label='$1/\phi \cdot x$')
ax.scatter(x, y)
ax.legend()
plt.show()
fig.savefig('test.jpg', bbox_inches='tight', dpi=300)

# %%
phi = (1 + 5 ** 0.5) / 2
y1 = list(filter(lambda x_i: x_i <= 80, list(map(lambda x_i: phi*x_i, x))))
y2 = list(map(lambda x_i: (1/phi)*x_i, x))

# %%
80/phi
# Out:
# 49.442719099991585

# %%
x1 = [i for i in range(50)]
y1 = [phi*i for i in range(50)]

# %%
plt.savefig('test.png')
